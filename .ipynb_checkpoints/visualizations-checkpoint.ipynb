# %% [markdown]
# # Visualizations

# %%
import os
import numpy as np
from IPython.display import HTML

from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    create_rhyme_dict,
    sample_sentence,
    sample_sonnet,
    sample_sonnet_syl_and_rhyme,
    visualize_sparsities,
    animate_emission,
    syllable_dict,
    sample_sonnet_syllables_only
)

# %% [markdown]
# ## Visualization of the dataset

# %% [markdown]
# We will be using Shakespeare's sonnets as our dataset. First, we visualize the entirety of Shakespeare's sonnets as a wordcloud:

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare_filt_1.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespeare')

# %% [markdown]
# ## Training various HMMs

# %% [markdown]
# Now we train a HMM on our dataset. We use 8 hidden states and train over 100 iterations. We chose 8 hidden states because that number of hidden states yielded the most comprehensible sonnets.

# %%
obs, obs_map = parse_observations(text)

# %%
hmm8 = unsupervised_HMM(obs, 8, 100)

# %% [markdown]
# ## Part G: Visualization of the sparsities of A and O

# %% [markdown]
# We can visualize the sparsities of the A and O matrices by treating the matrix entries as intensity values and showing them as images. What patterns do you notice?

# %%
visualize_sparsities(hmm8, O_max_cols=50)

# %% [markdown]
# ## Generating a sample sonnet

# %% [markdown]
# We will generate a sonnet using the naive form, 10 syllables, and 10 syllables with rhyming

# %%
print('Naive Sonnet:\n====================')
print(sample_sonnet(hmm8, obs_map, n_words=8))
# Out:
# Naive Sonnet:
# ====================
# Trees as first and a beauty this form
# Fair dear finds me esteemed hands is rolling
# Should date both candles none am and being
# Such lend to ne'er with heart my keeps
# Greatest his a o from that sweet'st thine
# Bear my whose merit our desire not you
# Am are gift me joy of fool cloud
# Fine hue hours main with thoughts a look
# These with this would each when in they
# Poor thou when vilest thy seem true thee
# The sin praise wail to impair on thou
# Are none stained in whilst my hang bending
# They never let since more eyes my that
# All beauty thee perfection thou love take and

# %%
print('10 Syllable Sonnet:\n====================')
print(sample_sonnet_syllables_only(hmm8, obs_map, n_syl=10))
# Out:
# 10 Syllable Sonnet:
# ====================
# Breast we with in vilest bring motion whit
# Be to like say thoughts than you prevent thy
# With thou to loves where death show but did bones
# Complexion dearest our but more so where
# Recured desire even anger and then not
# Had to loss interim upon and so and
# To trees thy nor eyes with live most have in
# Defect my in slight ay neglect what to
# Simplicity darkness grief morning for
# Moan buried his move seemed either ocean love's
# Parts thy where proud-pied in when not from love
# Heart sweet it the as doth thou of stole thee
# End and to frown dead care within the all
# Nor dost well swear of nor the and sweet place

# %%
rhyme_dict = create_rhyme_dict(text)
print('10 Syllable with Rhyming Sonnet:\n====================')
print(sample_sonnet_syl_and_rhyme(hmm8, obs_map, rhyme_dict, n_syl=10))
# Out:
# 10 Syllable with Rhyming Sonnet:
# ====================
# Which much when eyes their for trial feeding
# Whose world's adder's take time my love growing
# Have quenched wouldst number glory needing
# Saw for you words to not false that knowing
# In this of unknown doth in well treasure
# My gone god clouds despair as the jewel
# Writ for thy beauty dost to wound pleasure
# Look cruel why and in raven cruel
# Looks taken watchman and sweet counterfeit
# Whilst take ransom i common for thy good
# See absent steal and me not see unset
# Know as store then to and painting mine blood
# O thou in love and said lest judgement rest
# Sun so to o if perpetual last best

# %% [markdown]
# ## Part I: Visualizing the wordcloud of each state

# %% [markdown]
# Below, we visualize each state as a wordcloud by sampling a large emission from the state:

# %%
wordclouds = states_to_wordclouds(hmm8, obs_map)

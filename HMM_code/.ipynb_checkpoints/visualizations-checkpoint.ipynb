# %% [markdown]
# # Visualizations

# %%
import os
import numpy as np
from IPython.display import HTML

from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    create_rhyme_dict,
    sample_sentence,
    sample_sonnet,
    sample_sonnet_syl_and_rhyme,
    visualize_sparsities,
    animate_emission,
    syllable_dict,
    sample_sonnet_syllables_only
)

# %% [markdown]
# ## Visualization of the dataset

# %% [markdown]
# We will be using Shakespeare's sonnets as our dataset. First, we visualize the entirety of Shakespeare's sonnets as a wordcloud:

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare_filt_1.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespeare')

# %% [markdown]
# ## Training various HMMs

# %% [markdown]
# Now we train a HMM on our dataset. We use 8 hidden states and train over 100 iterations. We chose 8 hidden states because that number of hidden states yielded the most comprehensible sonnets.

# %%
obs, obs_map = parse_observations(text)

# %%
hmm8 = unsupervised_HMM(obs, 8, 100)

# %% [markdown]
# ## Part G: Visualization of the sparsities of A and O

# %% [markdown]
# We can visualize the sparsities of the A and O matrices by treating the matrix entries as intensity values and showing them as images. What patterns do you notice?

# %%
visualize_sparsities(hmm8, O_max_cols=100)

# %% [markdown]
# ## Generating a sample sonnet

# %% [markdown]
# We will generate a sonnet using the naive form, 10 syllables, and 10 syllables with rhyming

# %%
print('Naive Sonnet:\n====================')
print(sample_sonnet(hmm8, obs_map, n_words=8))
# Out:
# Naive Sonnet:
# ====================
# Are for the excuse translate a that region
# Statute and being green dear glass a and
# Pain wilt corrupting blunt he by full of
# None be love who face weep self and
# Was view if so of and mine disdaineth
# In yield loving mark in i pride must
# Except in to from plea where sweetest time
# Wires when yet for ashes what by shall
# Made state compound of lie his for thy
# Unswayed either's best sake but walks thee with
# The verse and the spurring we mad to
# Lest best thy the on rare will and
# Your ten o were and bastard theirs worthless
# And eclipses perfumes still perpetual less since parts

# %%
print('10 Syllable Sonnet:\n====================')
print(sample_sonnet_syllables_only(hmm8, obs_map, n_syl=10))
# Out:
# 10 Syllable Sonnet:
# ====================
# Time seldom call mistake so do numbers
# Horse hell thy not me a the do tongue you
# Eye said receiving thy the lively true
# Sweetest by seems under that to doth me
# Voices compass high to as maladies
# My carved like then maintain substance of mine
# Own the could large thou then memory my
# Die thy forged poor womb frown out and taste
# The song knows beauties not self men upon
# So bird away second friend which mutual
# Not alchemy than thou gives self see doth
# In though lord sake is fair joy not change lease
# When throw why it inferior life till dost
# When art and and commend dear you crime his

# %%
rhyme_dict = create_rhyme_dict(text)
print('10 Syllable with Rhyming Sonnet:\n====================')
print(sample_sonnet_syl_and_rhyme(hmm8, obs_map, rhyme_dict, n_syl=10))
# Out:
# 10 Syllable with Rhyming Sonnet:
# ====================
# Forgot form or wife every past adieu
# When thee spies is of richly i see please
# To distills thee o friend thou him that you
# My best others bright to tongue two disease
# To poor thy thoughts what sings of what but down
# Will sighs a where of self bloody the fight
# Is the awards more plea die knows nor frown
# With well and the my thee the dead sing quite
# To strange o though read invention transferred
# I others i heart for some with sets fears
# That i wished maladies termed rhyme keep erred
# Even self which comfort time's are can the tears
# Thy proud wilt wide making is then deny
# They most hand closet are and behold lie

# %% [markdown]
# ## Part I: Visualizing the wordcloud of each state

# %% [markdown]
# Below, we visualize each state as a wordcloud by sampling a large emission from the state:

# %%
wordclouds = states_to_wordclouds(hmm8, obs_map)
# Out:
# ['and', 'thou', 'is', 'to', 'my', 'thy', 'i', 'with', 'the', 'when']
# ['of', 'in', 'to', 'me', 'thy', 'that', 'for', 'be', 'i', 'love']
# ['my', 'and', 'to', 'is', 'that', 'of', 'i', 'it', 'in', 'be']
# ['and', 'my', 'to', 'i', 'that', 'the', 'but', 'for', 'of', 'his']
# ['to', 'of', 'thou', 'and', 'in', 'the', 'thy', 'that', 'it', 'i']
# ['and', 'thy', 'in', 'not', 'my', 'but', 'thou', 'i', 'me', 'for']
# ['the', 'to', 'i', 'with', 'of', 'my', 'that', 'all', 'but', 'a']
# ['the', 'and', 'that', 'my', 'with', 'in', 'be', 'i', 'when', 'of']

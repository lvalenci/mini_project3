# %% [markdown]
# # Visualizations

# %%
import os
import numpy as np
from IPython.display import HTML

from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    create_rhyme_dict,
    sample_sentence,
    sample_sonnet,
    sample_sonnet_syl_and_rhyme,
    visualize_sparsities,
    animate_emission,
    syllable_dict,
    sample_sonnet_syllables_only
)

# %% [markdown]
# ## Visualization of the dataset

# %% [markdown]
# We will be using Shakespeare's sonnets as our dataset. First, we visualize the entirety of Shakespeare's sonnets as a wordcloud:

# %%
text = open(os.path.join(os.getcwd(), 'data/shakespeare_filt_1.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespeare')

# %% [markdown]
# ## Training various HMMs

# %% [markdown]
# Now we train a HMM on our dataset. We use 8 hidden states and train over 100 iterations. We chose 8 hidden states because that number of hidden states yielded the most comprehensible sonnets.

# %%
obs, obs_map = parse_observations(text)

# %%
hmm8 = unsupervised_HMM(obs, 8, 100)

# %% [markdown]
# ## Part G: Visualization of the sparsities of A and O

# %% [markdown]
# We can visualize the sparsities of the A and O matrices by treating the matrix entries as intensity values and showing them as images. What patterns do you notice?

# %%
visualize_sparsities(hmm8, O_max_cols=100)

# %% [markdown]
# ## Generating a sample sonnet

# %% [markdown]
# We will generate a sonnet using the naive form, 10 syllables, and 10 syllables with rhyming

# %%
print('Naive Sonnet:\n====================')
print(sample_sonnet(hmm8, obs_map, n_words=8))
# Out:
# Naive Sonnet:
# ...
# Blunting be straight for gainst a my how
# Me keep that i can which dress tis
# Than not black of even the have art
# Truth know is thee thee still sometime i
# Verse love thee shames when the is me
# Mad at and that meadows both mayst behold
# Legacy you and by even and love's that
# Gold can built have that faults lamb have
# Aspect fair infection of to hath eye this
# Will love that in general outward his in
# I favour worse far a do you a
# But my by chronicle not both lusty love
# Dissuade pitied of them a yet dear you
# Forth will dear of beauty's those be mute

# %%
print('10 Syllable Sonnet:\n====================')
print(sample_sonnet_syllables_only(hmm8, obs_map, n_syl=10))
# Out:
# 10 Syllable Sonnet:
# ...
# In desired style deserts to could is
# You goest life mine in thou were conceit look
# Lines in love in reason remembered all
# Bail doth his mourners too that scarcely you
# Compounds read as translated princes as
# Brave saint thy contented who the use the
# Dead up their woo and self your of me this
# Substance so did love is in may betwixt
# The ill upon lines him should o'er-snowed none
# Gone teeth most do than separation for
# Loss forgot of not wrought necessary
# Other of so of beauty old see as
# Summer's even for as dost my woos take give
# Those a ground thus time a my years as all

# %%
rhyme_dict = create_rhyme_dict(text)
print('10 Syllable with Rhyming Sonnet:\n====================')
print(sample_sonnet_syl_and_rhyme(hmm8, obs_map, rhyme_dict, n_syl=10))
# Out:
# 10 Syllable with Rhyming Sonnet:
# ...
# That their outward thou love brought the my chase
# Fool i your born of truth o above being
# Grief the think drink eager there like thy face
# Tender to his back was when thy seeing
# Do force from in to in old true commend
# Leases forsake are hungry that wealth stay
# And tie is loving nothing which hue mend
# None with sessions for themselves mark away
# Me to in and utmost doth thou skill drink
# Of but none whate'er lives i deceived
# That brand i my if do praising him think
# I rights i thou of roses of perceived
# That in light love these is with year aside
# Tenants bearing sell imitate that pride

# %% [markdown]
# ## Part I: Visualizing the wordcloud of each state

# %% [markdown]
# Below, we visualize each state as a wordcloud by sampling a large emission from the state:

# %%
wordclouds = states_to_wordclouds(hmm8, obs_map)
